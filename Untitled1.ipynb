# %% [markdown]
# <a href="https://colab.research.google.com/github/svamplike/svamplike/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Notes For Mid Term**
#
# ---

# %% [markdown]
# **Tokens** : The smallest individual unit in a program is known as a **Token** or a **Lexical Unit**.

# %% [markdown]
# ![Screenshot 2022-06-14 160013.png](data:image/png;base64,...)

# %% [markdown]
# **Keywords** -: The resered keywords of python , which have a special fixed meaning for the interpreter are **keywords** ***No keywords can be used as identifiers***

# %% [markdown]
# **Literals** -: A fixed numeric or non numeric value is a **Literal** . It can be represented as a number , text or other data to be stored as variables.

# %% [markdown]
# **Identifiers** -: The name of any variable , constant, function or module is called an **identifier**. It is made up of combination of alphanumeric charecters. also underscore "_" , for multi line string use "/" or triple """

# %% [markdown]
# **Operators** -: An **Operator** is a symbol or a word that performs some kind of operation on given values and returns the result.

# %% [markdown]
# **Punctuators/Delimiters** -: These are symbols which can be used as a seperators of values or to enclose some values

# %%
n = 1
for  i in range(n,10):  # Operators:"%" , "=="
   if (i%2==0):         # Punctuators: "() , :" 
      print(i)          # Indentifier: "i" , "n"  # Literals : "n=1"
                        # Keywords : "range" , "print"

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ![download (2).png](data:image/png;base64,...)

# %%
 (3>2) and (3>5)
    #3>2 is false
# Out:
# False

# %%
(5<10) and (10<5) or (3<18) and not (8<18)
 #10<5 is false , (T and F or T and not T --> T and not T resulting in **False**)
# Out:
# False

# %% [markdown]
# ![download (1).png](data:image/png;base64,...)

# %% [markdown]
# **Variables**-: A variable is a container that stores values or data in memory which can be accessed or changed in a program later on.

# %%
new_var= 23
name="Rahul"

# %% [markdown]
# **Mutable** : those variables that can change their value in place

# %%
new_list = [1,2,3]
print(new_list)
# Out:
# [1, 2, 3]

# %% [markdown]
# If we change the values then:

# %%
new_list[0] = 100
print(new_list)
# Out:
# [100, 2, 3]

# %% [markdown]
# Therefore **List is mutable**

# %% [markdown]
# **Immutable** : Those variable that cannot change their values after creating them.

# %%
str = "Immute"
str[0] = 'p'
print(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 str = "Immute"
# ----> 2 str[0] = 'p'
#       3 print(str)
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Typerror due to the fact that **strings are immutable**
